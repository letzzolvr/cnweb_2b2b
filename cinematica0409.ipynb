# %% [markdown]
# <a href="https://colab.research.google.com/github/letzzolvr/cnweb_2b2b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da Velocidade Média

# %%
def CalcVelMedia(deltaS, deltaT):
  VelMedia = (deltaS / deltaT)
  return VelMedia

# %% [markdown]
# teste de serviço: velocidade média

# %%
print('Velocidade Média:',CalcVelMedia(50, 4))
# Out:
# Velocidade Média: 12.5
