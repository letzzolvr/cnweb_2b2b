# %% [markdown]
# <a href="https://colab.research.google.com/github/letzzolvr/cnweb_2b2b/blob/main/aula2603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exemplo** **de** **Serviço**

# %%
def soma(a, b):
  return (a+b)

# %%
soma(9, 68)
# Out:
# 77

# %% [markdown]
# #Sistema de Equações

# %%
import math

def eq2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return'equação sem solução'
  else:
      x1 = (-b + math.sqrt(delta)) / (2*a)
      x2 = (-b - math.sqrt(delta)) / (2*a)
      return x1, x2

# %%
print(eq2grau(1, -3, 2))
# Out:
# (2.0, 1.0)
